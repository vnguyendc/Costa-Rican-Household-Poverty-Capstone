# %% [markdown]
# # Exploring Costa Rican Households

# %%
#import necessaries libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Preparation

# %%
file_sample = 'sample_submission.csv'
file_test = 'test.csv'
file_train = 'train.csv'
sns.set()

# %%
sample = pd.read_csv(file_sample)

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23856 entries, 0 to 23855
# Data columns (total 2 columns):
# Id        23856 non-null object
# Target    23856 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 372.8+ KB

# %%
sample.sample(10)
# Out:
#                  Id  Target
# 10569  ID_1c29b1f19       4
# 6819   ID_2caaa8ebd       4
# 4966   ID_1e1f9400c       4
# 19310  ID_9870e46ea       4
# 4191   ID_f29b77588       4
# 1427   ID_94e599cb2       4
# 5638   ID_246903e5a       4
# 8092   ID_e6b9913f4       4
# 21527  ID_a4d6dd6f1       4
# 7590   ID_b97e341c7       4

# %%
test = pd.read_csv(file_test)
print ("Test Dataset: Rows, Columns: ", test.shape)
# Out:
# Test Dataset: Rows, Columns:  (23856, 142)

# %%
test.head(20)
# Out:
#               Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0   ID_2f6873615       NaN       0      5       0     1       1     0    NaN
# 1   ID_1c78846d2       NaN       0      5       0     1       1     0    NaN
# 2   ID_e5442cf6a       NaN       0      5       0     1       1     0    NaN
# 3   ID_a8db26a79       NaN       0     14       0     1       1     1    1.0
# 4   ID_a62966799  175000.0       0      4       0     1       1     1    1.0
# 5   ID_e77d38d45  400000.0       0      3       0     1       1     1    1.0
# 6   ID_3c5f4bd51  400000.0       0      3       0     1       1     1    1.0
# 7   ID_a849c29bd  300000.0       0      6       0     1       1     1    1.0
# 8   ID_472fa82da  300000.0       0      6       0     1       1     1    1.0
# 9   ID_24864adcc       NaN       0      6       0     1       1     0    NaN
# 10  ID_247909995   90000.0       0      5       0     1       1     0    NaN
# 11  ID_fbe8d0909   90000.0       0      5       0     1       1     0    NaN
# 12  ID_8ed30c46a   90000.0       0      5       0     1       1     0    NaN
# 13  ID_c8809fe15  200000.0       0      5       0     1       1     0    NaN
# 14  ID_b726eb052  200000.0       0      5       0     1       1     0    NaN
# 15  ID_3533dffe1  200000.0       0      5       0     1       1     0    NaN
# 16  ID_67a331b9f  200000.0       0      5       0     1       1     0    NaN
# 17  ID_67c4a6bb6  200000.0       0      5       0     1       1     0    NaN
# 18  ID_8228c6a2e  200000.0       0      5       0     1       1     0    NaN
# 19  ID_d54f1a82e  240000.0       0      6       0     1       1     0    NaN
#
#     r4h1  ...    age  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  \
# 0      1  ...      4            0      16               9          0
# 1      1  ...     41          256    1681               9          0
# 2      1  ...     41          289    1681               9          0
# 3      0  ...     59          256    3481               1        256
# 4      0  ...     18          121     324               1          0
# 5      0  ...     38          256    1444               4          0
# 6      0  ...     42          121    1764               4          0
# 7      0  ...     21          196     441               4          0
# 8      0  ...     22          196     484               4          0
# 9      0  ...     70          100    4900               1          0
# 10     0  ...     18          100     324               9          0
# 11     0  ...     55           81    3025               9          0
# 12     0  ...     53          225    2809               9          0
# 13     0  ...     51          100    2601              36        100
# 14     0  ...     52          121    2704              36        100
# 15     0  ...     15           81     225              36        100
# 16     0  ...     22           81     484              36        100
# 17     0  ...     21          144     441              36        100
# 18     0  ...     17          100     289              36        100
# 19     0  ...     27           81     729               9         36
#
#     SQBhogar_nin  SQBovercrowding  SQBdependency  SQBmeaned  agesq
# 0              1         2.250000           0.25     272.25     16
# 1              1         2.250000           0.25     272.25   1681
# 2              1         2.250000           0.25     272.25   1681
# 3              0         1.000000           0.00     256.00   3481
# 4              1         0.250000          64.00        NaN    324
# 5              0         1.000000           0.00     182.25   1444
# 6              0         1.000000           0.00     182.25   1764
# 7              0         0.250000           0.00     196.00    441
# 8              0         0.250000           0.00     196.00    484
# 9              0         0.111111          64.00     100.00   4900
# 10             1         1.000000           0.25     289.00    324
# 11             1         1.000000           0.25     289.00   3025
# 12             1         1.000000           0.25     289.00   2809
# 13             4         4.000000           0.25     110.25   2601
# 14             4         4.000000           0.25     110.25   2704
# 15             4         4.000000           0.25     110.25    225
# 16             4         4.000000           0.25     110.25    484
# 17             4         4.000000           0.25     110.25    441
# 18             4         4.000000           0.25     110.25    289
# 19             0         0.562500           0.00      64.00    729
#
# [20 rows x 142 columns]

# %%
train = pd.read_csv(file_train)
print ("Train Dataset: Rows, Columns: ", train.shape)
# Out:
# Train Dataset: Rows, Columns:  (9557, 143)

# %% [markdown]
# #### Test Dataset

# %% [markdown]
# #### Train Dataset

# %%
train[train['Target'] != 4].sample(10)
# Out:
#                 Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  \
# 8651  ID_d7dcb72ab       NaN       0      5       0     1       1     0
# 5721  ID_4bd014967   70000.0       0      5       0     1       1     0
# 4859  ID_4ebd3c079       NaN       0      4       1     1       1     0
# 9196  ID_69592cb6b       NaN       0      4       0     1       1     0
# 9479  ID_5e06f0d81       0.0       0      4       0     1       1     0
# 9452  ID_c51d7c66b       NaN       0      6       0     1       1     0
# 8011  ID_a99ed35e1       NaN       0      4       0     1       1     0
# 2302  ID_c763a0fb4  150000.0       0      5       0     1       1     0
# 7912  ID_6f8913c57   85000.0       0      4       0     1       1     0
# 1232  ID_9311adb96       NaN       0      7       0     1       1     0
#
#       v18q1  r4h1   ...    SQBescolari  SQBage  SQBhogar_total  SQBedjefe  \
# 8651    NaN     0   ...            121     576               4        121
# 5721    NaN     0   ...              0    4900              25          0
# 4859    NaN     2   ...              9    6084              81          9
# 9196    NaN     1   ...              0       9               9         36
# 9479    NaN     1   ...              4     100              36          4
# 9452    NaN     0   ...             36    1089              49          0
# 8011    NaN     0   ...             36    4096               4          9
# 2302    NaN     1   ...              0      49              25          0
# 7912    NaN     3   ...             16     121              25          0
# 1232    NaN     0   ...              0    1600              16          0
#
#       SQBhogar_nin  SQBovercrowding  SQBdependency   SQBmeaned  agesq  Target
# 8651             0           1.5625         0.0000  121.000000    576       1
# 5721             1           6.2500         2.2500   33.062500   4900       3
# 4859             9           9.0000         4.0000   34.027779   6084       1
# 9196             1           2.2500         0.2500   36.000000      9       2
# 9479            16           9.0000         4.0000    9.000000    100       2
# 9452             4           3.0625         0.5625   12.959999   1089       3
# 8011             0           1.0000         0.0000   20.250000   4096       1
# 2302             9           6.2500         2.2500   81.000000     49       2
# 7912             9           6.2500         2.2500   90.250000    121       1
# 1232             0           1.9600         0.0000   25.000000   1600       2
#
# [10 rows x 143 columns]

# %%
train.describe()
# Out:
#                v2a1       hacdor        rooms       hacapo         v14a  \
# count  2.697000e+03  9557.000000  9557.000000  9557.000000  9557.000000
# mean   1.652316e+05     0.038087     4.955530     0.023648     0.994768
# std    1.504571e+05     0.191417     1.468381     0.151957     0.072145
# min    0.000000e+00     0.000000     1.000000     0.000000     0.000000
# 25%    8.000000e+04     0.000000     4.000000     0.000000     1.000000
# 50%    1.300000e+05     0.000000     5.000000     0.000000     1.000000
# 75%    2.000000e+05     0.000000     6.000000     0.000000     1.000000
# max    2.353477e+06     1.000000    11.000000     1.000000     1.000000
#
#             refrig         v18q        v18q1         r4h1         r4h2  \
# count  9557.000000  9557.000000  2215.000000  9557.000000  9557.000000
# mean      0.957623     0.231767     1.404063     0.385895     1.559171
# std       0.201459     0.421983     0.763131     0.680779     1.036574
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# 25%       1.000000     0.000000     1.000000     0.000000     1.000000
# 50%       1.000000     0.000000     1.000000     0.000000     1.000000
# 75%       1.000000     0.000000     2.000000     1.000000     2.000000
# max       1.000000     1.000000     6.000000     5.000000     8.000000
#
#           ...       SQBescolari       SQBage  SQBhogar_total    SQBedjefe  \
# count     ...       9557.000000  9557.000000     9557.000000  9557.000000
# mean      ...         74.222769  1643.774302       19.132887    53.500262
# std       ...         76.777549  1741.197050       18.751395    78.445804
# min       ...          0.000000     0.000000        1.000000     0.000000
# 25%       ...         16.000000   289.000000        9.000000     0.000000
# 50%       ...         36.000000   961.000000       16.000000    36.000000
# 75%       ...        121.000000  2601.000000       25.000000    81.000000
# max       ...        441.000000  9409.000000      169.000000   441.000000
#
#        SQBhogar_nin  SQBovercrowding  SQBdependency    SQBmeaned        agesq  \
# count   9557.000000      9557.000000    9557.000000  9552.000000  9557.000000
# mean       3.844826         3.249485       3.900409   102.588867  1643.774302
# std        6.946296         4.129547      12.511831    93.516890  1741.197050
# min        0.000000         0.040000       0.000000     0.000000     0.000000
# 25%        0.000000         1.000000       0.111111    36.000000   289.000000
# 50%        1.000000         2.250000       0.444444    81.000000   961.000000
# 75%        4.000000         4.000000       1.777778   134.560010  2601.000000
# max       81.000000        36.000000      64.000000  1369.000000  9409.000000
#
#             Target
# count  9557.000000
# mean      3.302292
# std       1.009565
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       4.000000
# max       4.000000
#
# [8 rows x 138 columns]

# %% [markdown]
# ## *Data Cleaning*

# %%
nullval = train.isnull().sum().to_frame().sort_values(0, ascending = False)
nullval.head(10)
# Out:
#                  0
# rez_esc       7928
# v18q1         7342
# v2a1          6860
# SQBmeaned        5
# meaneduc         5
# Id               0
# hogar_adul       0
# parentesco10     0
# parentesco11     0
# parentesco12     0

# %% [markdown]
# ##### Columns with missing values:
#
# rez_esc, Years behind in school
#
# v18q1, Number of tablets in home
#
# v2a1, Monthly rent payment
#
# SQBmeaned, square of the mean years of education of adults (>=18) in the household
#
# meaneduc,average years of education for adults (18+)

# %% [markdown]
# ### There's a lot of missing values for `rez_esc`, `v18q1`, and `v2a1`. We should find out why.

# %%
train['rez_esc'].unique()
# Out:
# array([nan,  1.,  0.,  3.,  2.,  4.,  5.])

# %% [markdown]
# This variable refers to how many years someone is behind in school. It would make sense to look at their age and level of education.

# %%
nan = train[train['rez_esc'].isnull()]
nan[['rez_esc', 'age', 'edjefe', 'edjefa', 'escolari', 'instlevel2', 'instlevel4', 'instlevel6', ]].head(20)
# Out:
#     rez_esc  age edjefe edjefa  escolari  instlevel2  instlevel4  instlevel6
# 0       NaN   43     10     no        10           0           1           0
# 1       NaN   67     12     no        12           0           0           0
# 2       NaN   92     no     11        11           0           0           0
# 4       NaN   37     11     no        11           0           0           0
# 5       NaN   38     11     no        11           0           0           0
# 8       NaN   30      9     no         9           0           1           0
# 9       NaN   28      9     no        11           0           0           0
# 11      NaN   18     no     11        12           0           0           0
# 12      NaN   34     no     11        11           0           0           0
# 13      NaN   79     no      4         4           1           0           0
# 14      NaN   39     no      4        15           0           0           0
# 15      NaN   19     no     10        11           0           0           0
# 16      NaN   70     no     10         2           1           0           0
# 17      NaN   19     no     10        11           0           0           0
# 18      NaN   50     no     10        10           0           1           0
# 19      NaN   22     15     no        12           0           0           0
# 20      NaN   26     15     no        15           0           0           0
# 21      NaN   69      4     no         4           1           0           0
# 22      NaN   66      4     no        16           0           0           0
# 23      NaN   41      6     no         6           0           0           0

# %%
plt.hist(nan[nan['age']<30]['age'], bins=30)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# It seems like there is almost no one between the ages of 6 to 18, meaning that these null values are because these individuals are not in school. Therefore we can fill these values in as 0.

# %%
train['rez_esc']=train['rez_esc'].fillna(0)

# %% [markdown]
# ### `v18q1`

# %% [markdown]
# This variable refers to the number of tablets a household owns. Probably null because these households just don't own tablets.

# %%
train[train['v18q1'].isnull()][['v18q1', 'v18q']].head(20)
# Out:
#     v18q1  v18q
# 0     NaN     0
# 2     NaN     0
# 7     NaN     0
# 8     NaN     0
# 9     NaN     0
# 10    NaN     0
# 11    NaN     0
# 12    NaN     0
# 15    NaN     0
# 16    NaN     0
# 17    NaN     0
# 18    NaN     0
# 19    NaN     0
# 20    NaN     0
# 21    NaN     0
# 22    NaN     0
# 23    NaN     0
# 24    NaN     0
# 25    NaN     0
# 26    NaN     0

# %%
nan = train[train['v18q1'].isnull()]
print('Households with tablets: ', sum(nan.v18q))
# Out:
# Households with tablets:  0

# %% [markdown]
# There we go. Let's fill these in with 0.

# %%
train['v18q1'] = train['v18q1'].fillna(0)

# %% [markdown]
# ### `v2a1`

# %% [markdown]
# This refers to the monthly rent the individual pays for their household. Could be related to whether their housing situation.

# %%
housing_nan = train[train['v2a1'].isnull()][['v2a1', 'tipovivi1', 'tipovivi2', 'tipovivi3', 'tipovivi4', 'tipovivi5']]
housing_nan.sample(10)
# Out:
#       v2a1  tipovivi1  tipovivi2  tipovivi3  tipovivi4  tipovivi5
# 7762   NaN          1          0          0          0          0
# 6888   NaN          0          0          0          1          0
# 4540   NaN          1          0          0          0          0
# 1658   NaN          0          0          0          1          0
# 5278   NaN          1          0          0          0          0
# 3842   NaN          1          0          0          0          0
# 4617   NaN          1          0          0          0          0
# 2926   NaN          1          0          0          0          0
# 1317   NaN          1          0          0          0          0
# 3026   NaN          1          0          0          0          0

# %%
housing_nan.sum()
# Out:
# v2a1            0.0
# tipovivi1    5911.0
# tipovivi2       0.0
# tipovivi3       0.0
# tipovivi4     163.0
# tipovivi5     786.0
# dtype: float64

# %% [markdown]
# 5911 of these records own houses, 163 are precarious, and 786 are other. None are rented homes nor paying installments. We can fill these in with 0.

# %%
train['v2a1'] = train['v2a1'].fillna(0)

# %% [markdown]
# ### `SQBmeaned` and `meaneduc` ?

# %% [markdown]
# * `meaneduc` = average years of education for adults (18+)
# * `SQBmeaned` = square of the mean years of education of adults (>=18) in the household

# %%
train[['meaneduc']].head(10)
# Out:
#    meaneduc
# 0      10.0
# 1      12.0
# 2      11.0
# 3      11.0
# 4      11.0
# 5      11.0
# 6      11.0
# 7      10.0
# 8      10.0
# 9      10.0

# %%
train[train['meaneduc'].isnull()][['idhogar', 'age', 'tamviv', 'rez_esc', 'escolari', 'meaneduc', 'SQBmeaned']]
# Out:
#         idhogar  age  tamviv  rez_esc  escolari  meaneduc  SQBmeaned
# 1291  1b31fd159   18       1      0.0        10       NaN        NaN
# 1840  a874b7ce7   18       2      0.0         6       NaN        NaN
# 1841  a874b7ce7   18       2      0.0         4       NaN        NaN
# 2049  faaebf71a   19       2      0.0        12       NaN        NaN
# 2050  faaebf71a   19       2      0.0        12       NaN        NaN

# %% [markdown]
# These are only 3 houses and none of the household members are probably still in school. Looking at `tamviv` they are the only members in their household. We can just take the mean of `escolari` for each household and put it into `meaneduc` then `SQBmeaned`.

# %%
meaneduc_nan=train[train['meaneduc'].isnull()][['Id','idhogar','escolari']]
me=meaneduc_nan.groupby('idhogar')['escolari'].mean().reset_index()
me
# Out:
#      idhogar  escolari
# 0  1b31fd159        10
# 1  a874b7ce7         5
# 2  faaebf71a        12

# %%
for row in meaneduc_nan.iterrows():
    idx=row[0]
    idhogar=row[1]['idhogar']
    m=me[me['idhogar']==idhogar]['escolari'].tolist()[0]
    train.at[idx, 'meaneduc']=m
    train.at[idx, 'SQBmeaned']=m*m

# %%
nullval = train.isnull().sum().to_frame().sort_values(0, ascending = False)
nullval.head(10)
# Out:
#               0
# Id            0
# hogar_mayor   0
# parentesco10  0
# parentesco11  0
# parentesco12  0
# idhogar       0
# hogar_nin     0
# hogar_adul    0
# hogar_total   0
# parentesco8   0

# %% [markdown]
# *All missing values accounted for.*

# %% [markdown]
# ## *Data Wrangling*

# %% [markdown]
# Replace `int` `Target` values with the `str` values.

# %%
train1 = train.copy()
train1['Target'].replace([1,2,3,4],['Extreme Poverty','Moderate Poverty','Vulnerable','Non Vulnerable'],inplace=True)

# %%
target = train1['Target'].value_counts().to_frame()
levels = train1['Target'].unique()
plt.bar(levels, target.Target, align='center')
plt.xlabel('Poverty Level')
plt.ylabel('Frequency')
plt.title('Household Poverty Levels')
plt.show()

# %%
mean_rent = train1.groupby(['Target']).mean()['v2a1']
#bargraph
plt.bar(levels, mean_rent, align='center')
plt.xlabel('Poverty Level')
plt.ylabel('Monthly Rent Payment ($)')
plt.title('Average Montly Rent per Poverty Level')
plt.show()

sns.boxplot(x='Target', y='v2a1', data=train1)
plt.xlabel('Poverty Level')
plt.ylabel('Monthly Rent Payment ($)')
plt.show()

# %% [markdown]
# We see we have two outstanding outliers in Non Vulnerable. Let's get rid of those two to get a better look at the distribution.

# %%
train = train[train['v2a1'] < 2000000]
train1 = train1[train1['v2a1'] < 2000000]

# %%
mean_rent = train1.groupby(['Target']).mean()['v2a1']
#bargraph
plt.bar(levels, mean_rent, align='center')
plt.xlabel('Poverty Level')
plt.ylabel('Monthly Rent Payment ($)')
plt.title('Average Montly Rent per Poverty Level')
plt.show()

sns.boxplot(x='Target', y='v2a1', data=train1)
plt.xlabel('Poverty Level')
plt.ylabel('Monthly Rent Payment ($)')
plt.show()

# %%
#ecdf
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""
    # Number of data points: n
    n = len(data)
    # x-data for the ECDF: x
    x = np.sort(data)
    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n
    return x, y

# %% [markdown]
# Lot of missing values for rent payment to account for. Fill in missing data. Do swarmplot. do significance testing. use bs replicates and confidence interval

# %%
mean_rooms = train1.groupby(['Target']).mean()['rooms']
#swarmplot
_ = sns.swarmplot(x='Target', y='rooms', data=train1)
_ = sns.boxplot(x='Target', y='rooms', data=train1)
plt.xlabel('Poverty Level')
plt.ylabel('# of Rooms')
plt.title('Average # of Rooms per Poverty Level')
plt.show()

# %% [markdown]
# Tells deviation on the mean

# %%
#histogram
plt.hist(train1[train1['Target'] == 'Non Vulnerable']['rooms'])
plt.xlabel('# of Rooms')
plt.ylabel('Frequency')
plt.title('Non Vulnerable')
plt.show()

plt.hist(train1[train1['Target'] == 'Vulnerable']['rooms'])
plt.xlabel('# of Rooms')
plt.ylabel('Frequency')
plt.title('Vulnerable')
plt.show()

plt.hist(train1[train1['Target'] == 'Moderate Poverty']['rooms'])
plt.xlabel('# of Rooms')
plt.ylabel('Frequency')
plt.title('Moderate Poverty')
plt.show()

plt.hist(train1[train1['Target'] == 'Extreme Poverty']['rooms'])
plt.xlabel('# of Rooms')
plt.ylabel('Frequency')
plt.title('Extreme Poverty')
plt.show()

# %% [markdown]
# Make a function for these histograms

# %%
#scatterplot
plt.plot(train1['rooms'], train1['v2a1'], marker = '.', linestyle = 'none')
plt.xlabel('Rooms')
plt.ylabel('Monthly Rent')
plt.title('Rooms vs Rent')
plt.show()
